# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.sparse import spdiags
import pde

xi = 0
xf = 200e3
zi = 0
zf = 20e3
nx = 200
nz = 200
x = np.linspace(xi, xf, nx + 1)
z = np.linspace(zi, zf, nz + 1)
nx = len(x)
nz = len(z)
g = 9.8
T0 = 288
adiabatic_lapse_rate = 9.8
avg_temp_gradient = 6.5
N2 = g/T0 * np.abs(adiabatic_lapse_rate - avg_temp_gradient)/1000
ubar = 2.0

# %% [markdown]
# I have tried to figure out how to use pde for over 12h (over multiple days by the way) but I don't know how to do time derivatives with second order stuff and have asked multiple AIs and my groupmate for help and we can't figure it out. Furthermore, it looks like Nick wasn't available for a significant period of time before this as well and I've been trying my hardest to get this all to run but it's just been a disaster.
# By the way, we are trying to implement equation 7.42 and 7.46. But the higher-order derivatives have us completely stuck. We are aware that the initial condition must be a perturbation and in 7.42 we assume a flat surface, but we can add a vertical velocity as initial condition at z=0 when considering terrain (for 7.46). Height is 20km, width is 200km. We plan to eventually plot the wave going across the screen.

# %% [markdown]
# I am desperate. Please help.
